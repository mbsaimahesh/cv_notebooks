# %%
import rawpy
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import rawpy
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'rawpy'

# %%
raw_img = rawpy.imread('/home/sravya/Code/Data/raw_images/IMG_20211029_212605.dng')
rgb_img = rawpy.RawPy.postprocess(raw_img)

# %%
raw_img.sizes.raw_height
# Out:
# 3120

# %%
def demosaic(raw_img):
    rgb = np.zeros((raw_img.sizes.raw_height, raw_img.sizes.raw_width,3))
    print(rgb.shape)
    print(rgb.dtype)

# %%
plt.imshow(rgb_img)
