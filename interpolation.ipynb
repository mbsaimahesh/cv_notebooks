# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
im = cv2.imread('/home/sravya/Code/Data/standard_test_images/lena_gray_256.tif',cv2.IMREAD_GRAYSCALE)
plt.imshow(im,cmap='gray')

# %%
h= (1/16)*np.array([1,4,6,4,1])
s= im[128,:]

# %%
s_pix = 0
for i in range(-2,2):
    for j in range(-2,2):
        s_pix+=(im[i,j]*h[
